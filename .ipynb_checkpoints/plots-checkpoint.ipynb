# %%
from plot_tools import *

# %%
'''
def create_performance_barplot(
    baseline_policy: str,
    policies: List[str],
    workloads: List[str],
    statistic: str = "KIPS",
    section: str = "CLIENT_0",
    data_dir: str = "out/qmem/simulation_results",
    figsize: Tuple[float, float] = (12, 6),
    colors: Optional[List[str]] = None,
    bar_width: float = 0.8,
    ylabel: str = "Relative Performance",
    ylabel_fontsize: int = 12,
    xlabel_fontsize: int = 12,
    show_values: bool = True,
    percent_improvement: bool = False
'''
for c in [4, 8, 12, 16, 24]:
    fig = create_performance_barplot('viszlai',
                                     ['dpt'],
                                     ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256'],
                                     statistic='MEMORY_INSTRUCTIONS',
                                     section=None,
                                     data_dir='out/qmem/compiled_results',
                                     is_simulation_stats=False,
                                     figsize=(5, 3),
                                     ylabel='Relative Mem. Ops',
                                     xlabel_fontsize=10,
                                     show_values=True,
                                     percent_improvement=False,
                                     ext=f'c{c}',
                                     plotting_slowdown=False)
    plt.savefig(f'plots/qmem/reduction_mem_ops_c{c}.pdf', bbox_inches='tight')

    fig = create_performance_barplot('viszlai_near_memory',
                                     ['viszlai', 'dpt'],
                                     ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256'],
                                     statistic='KIPS',
                                     section='CLIENT_0',
                                     data_dir='out/qmem/simulation_results',
                                     is_simulation_stats=True,
                                     figsize=(5,3),
                                     ylabel='Slowdown',
                                     xlabel_fontsize=10,
                                     show_values=True,
                                     percent_improvement=False,
                                     ext=f'c{c}',
                                     plotting_slowdown=True)
    plt.savefig(f'plots/qmem/speedup_c{c}.pdf', bbox_inches='tight')
# Out:
# viszlai {'cr2_120': 878479, 'ethylene_240': 476503, 'hc3h2cn_288': 480760, 'shor_RSA256': 115653}
# dpt {'cr2_120': 866744, 'ethylene_240': 697049, 'hc3h2cn_288': 653235, 'shor_RSA256': 48966}
# dpt cr2_120 0.9866416840926192
# dpt ethylene_240 1.4628428362465713
# dpt hc3h2cn_288 1.3587548880938514
# dpt shor_RSA256 0.4233872013696143
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# dpt [0.9866416840926192, 1.4628428362465713, 1.3587548880938514, 0.4233872013696143, 0.9545726643197032]
# viszlai_near_memory {'cr2_120': 2.94915, 'ethylene_240': 7.17758, 'hc3h2cn_288': 11.7387, 'shor_RSA256': 20.0693}
# viszlai {'cr2_120': 0.130711, 'ethylene_240': 0.360579, 'hc3h2cn_288': 0.368612, 'shor_RSA256': 1.8063}
# dpt {'cr2_120': 0.181166, 'ethylene_240': 0.295346, 'hc3h2cn_288': 0.320711, 'shor_RSA256': 2.86821}
# viszlai cr2_120 22.56237042024007
# viszlai ethylene_240 19.90570720979314
# viszlai hc3h2cn_288 31.84568055299339
# viszlai shor_RSA256 11.110723578586057
# dpt cr2_120 16.278716757007384
# dpt ethylene_240 24.3022759746196
# dpt hc3h2cn_288 36.60211218199563
# dpt shor_RSA256 6.997151533534852
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# viszlai [18.08176428391875, 16.02416683777776, 27.06863580858466, 7.969402333518533, 15.81164648109314]
# dpt [8.248144356999424, 2.000646479057701, 3.0593081754455405, 2.903978250495293, 3.4796518892768806]
# viszlai {'cr2_120': 610824, 'ethylene_240': 316261, 'hc3h2cn_288': 339307, 'shor_RSA256': 85608}
# dpt {'cr2_120': 352083, 'ethylene_240': 53343, 'hc3h2cn_288': 57923, 'shor_RSA256': 20048}
# dpt cr2_120 0.5764066244941259
# dpt ethylene_240 0.16866765108565393
# dpt hc3h2cn_288 0.17070971126443016
# dpt shor_RSA256 0.2341837211475563
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# dpt [0.5764066244941259, 0.16866765108565393, 0.17070971126443016, 0.2341837211475563, 0.249685845176236]
# viszlai_near_memory {'cr2_120': 2.94918, 'ethylene_240': 7.17823, 'hc3h2cn_288': 11.7487, 'shor_RSA256': 20.0811}
# viszlai {'cr2_120': 0.169187, 'ethylene_240': 0.520527, 'hc3h2cn_288': 0.476198, 'shor_RSA256': 3.25597}
# dpt {'cr2_120': 0.566393, 'ethylene_240': 4.32788, 'hc3h2cn_288': 4.45706, 'shor_RSA256': 8.99627}
# viszlai cr2_120 17.431481142168135
# viszlai ethylene_240 13.790312510206004
# viszlai hc3h2cn_288 24.671880184293087
# viszlai shor_RSA256 6.167470830505195
# dpt cr2_120 5.20694994464974
# dpt ethylene_240 1.6586019020860094
# dpt hc3h2cn_288 2.6359752841559234
# dpt shor_RSA256 2.2321584389974953
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# viszlai [17.431481142168135, 13.790312510206004, 24.671880184293087, 6.167470830505195, 13.829435001898947]
# dpt [5.20694994464974, 1.6586019020860094, 2.6359752841559234, 2.2321584389974953, 2.6699183384814806]
# viszlai {'cr2_120': 543713, 'ethylene_240': 275298, 'hc3h2cn_288': 322784, 'shor_RSA256': 53471}
# dpt {'cr2_120': 144123, 'ethylene_240': 39083, 'hc3h2cn_288': 57337, 'shor_RSA256': 14059}
# dpt cr2_120 0.26507183017511077
# dpt ethylene_240 0.14196616030628628
# dpt hc3h2cn_288 0.177632720333102
# dpt shor_RSA256 0.2629275682145462
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# dpt [0.26507183017511077, 0.14196616030628628, 0.177632720333102, 0.2629275682145462, 0.20475139819157495]
# viszlai_near_memory {'cr2_120': 2.94917, 'ethylene_240': 7.17908, 'hc3h2cn_288': 11.7486, 'shor_RSA256': 20.0788}
# viszlai {'cr2_120': 0.192553, 'ethylene_240': 0.570948, 'hc3h2cn_288': 0.520745, 'shor_RSA256': 5.13043}
# dpt {'cr2_120': 1.3822, 'ethylene_240': 5.1261, 'hc3h2cn_288': 4.82615, 'shor_RSA256': 11.5462}
# viszlai cr2_120 15.316146723239834
# viszlai ethylene_240 12.57396470431633
# viszlai hc3h2cn_288 22.561138369067393
# viszlai shor_RSA256 3.913668055114289
# dpt cr2_120 2.133678194183186
# dpt ethylene_240 1.4004955034041473
# dpt hc3h2cn_288 2.4343627943598936
# dpt shor_RSA256 1.7389963797613068
# ['cr2_120', 'ethylene_240', 'hc3h2cn_288', 'shor_RSA256', 'Geomean']
# viszlai [15.316146723239834, 12.57396470431633, 22.561138369067393, 3.913668055114289, 11.419357985765135]
# dpt [2.133678194183186, 1.4004955034041473, 2.4343627943598936, 1.7389963797613068, 1.88592168551729]
