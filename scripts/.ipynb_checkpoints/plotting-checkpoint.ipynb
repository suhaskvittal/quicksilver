# %%
# author: Suhas Vittal

# %%
import sys
import os
sys.path.insert(0, 'scripts')

print(os.getcwd())

from plotting_util import *
# Out:
# /Users/svittal/Documents/research/q/quicksilver/scripts

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
C1 = '#1f4529'
C2 = '#f5f4b3'
C3 = '#abba7c'
C4 = '#898121'

# %%
def _nested_dict_access(stats: dict, key: str) -> str:
    '''
        This function accesses `stats` and handle nesting.

        So, for example, if `key` is just `COMPUTE_FREQ_KHZ`, then
        `stats['COMPUTE_FREQ_KHZ']` is returned.

        If `key` is 'CLIENT 0/IPdC', then `stats['CLIENT 0']['IPdC']` is returned.
    '''
    parts = key.split('/')
    d = stats
    for p in parts:
        if p not in d:
            print(f'dictionary does not have index {p}:', d.keys())
        d = d[p]
    return d

def plot_stat(ax,
                benchmark_list: list[str], 
                benchmark_ticks: list[str], 
                legend: list[str],
                configs: list[dict],
                colors: list[str],
                stat_key: str, 
                ylabel: str,
                ylim=None,
                legend_ncols=1,
                normalize_results_to_policy=None,
                inverted_normalization=False,
                mean_type=None,
                show_percentage=False
):
    '''
        `ax`: the matplotlib axis to be modified
        `benchmark_list`: list of benchmarks to plot for
        `benchmark_ticks`: how these benchmarks appear on the x-axis
        `legend`: list of policies to plot for
        `configs`: the statistics dictionaries for each policy
        `colors`: bar colors for each policy
        `stat_key`: path to access each policy's dictionary (see `_nested_dict_access()` above)
        `ylabel`: y-axis label

        Optionals:
            `ylim`: (ymin, ymax) tuple. If provided, the y-axis is clamped to this range,
                and any bar whose true value exceeds ymax gets a text annotation showing
                the true value.
            `legend_ncols`: number of columns for matplotlib legend
            `normalize_results_to_policy`: if none, then results are not normalized. If not none, then
                the results are normalized to the given policy (and that policy is not plotted).
                Note that `normalize_results_to_policy` will automatically modify `legends`, `configs`,
                and `colors` to remove the normalized policy, so the caller does not have to worry about this.
            `inverted_normalization`: do `reference_value/x` instead of `x/reference_value`. This is useful
                for showing slowdowns.
            `mean_type`: choose one of "amean" (arithmetic), "gmean" (geometric), "hmean" (harmonic), or
                        None if no mean is desired
    '''
    ax.set_ylabel(ylabel, fontsize=12)

    # modify the inputs depending on the optional parameters
    policy_count = len(legend)
    if normalize_results_to_policy is not None:
        policy_count -= 1  # we will not plot the reference poliy
        reference_idx = legend.index(normalize_results_to_policy)
                
    if mean_type is not None:
        benchmark_ticks = [*benchmark_ticks, mean_type]
    
    # compute some values we need for plotting:    
    benchmark_x = np.arange(len(benchmark_ticks))
    width = 1.0 / (policy_count+1)
    offset = 0

    # do the plotting:
    for (i, policy) in enumerate(legend):
        if policy == normalize_results_to_policy:
            continue
        Y = []
        for b in benchmark_list:
            y = float(_nested_dict_access(configs[i][b], stat_key))
            if normalize_results_to_policy is not None:
                reference_value = float(_nested_dict_access(configs[reference_idx][b], stat_key))
                if inverted_normalization:
                    y = reference_value/y
                else:
                    y /= reference_value
            Y.append(y)

        # add the mean if necessary
        if mean_type == 'amean':
            Y.append(sum(Y)/len(Y))
        elif mean_type == 'gmean':
            Y.append(sp.stats.gmean(Y))
        Y = np.array(Y)

        # update stats to show percentage:
        if show_percentage:
            if normalize_results_to_policy is None:
                Y *= 100
            else:
                Y = (Y-1)*100
        
        print(policy, Y[-1], min(Y), max(Y), Y)
        ax.bar(benchmark_x+offset, Y, width, color=colors[i], edgecolor='k', zorder=3, label=policy)
        offset += width

    # apply ylim and annotate any bars whose true value exceeds the upper limit
    if ylim is not None:
        ax.set_ylim(ylim)
        ymax = ylim[1]
        for patch in ax.patches:
            v = patch.get_height()
            if v > ymax:
                x = patch.get_x() + patch.get_width() / 2
                ax.text(x, ymax, f'{v:.3g}', ha='center', va='bottom', fontsize=10)

    workload_x_ticks = benchmark_x + (policy_count-1)/2 * width
    ax.set_xticks(workload_x_ticks, benchmark_ticks, rotation=30, ha='right', fontsize=10)
    ax.grid(visible=True, axis='y', zorder=0)
    if policy_count > 1:
        ax.legend(fontsize=10, ncols=legend_ncols)

# %%
PLOT_FOLDER = 'plots/hint'#'../../../writing/disaggregated_memory_systems/figures'
STATS_FOLDER = '../out/hint_isca2026'
BENCHMARKS = ['BQ_shor_rsa256_iter_4',
              'BQ_grover_3sat_schoning_1710',
              'BQ_e_cr2_120_trotter',
              'BQ_v_c2h4o_ethylene_oxide_240_trotter',
              'BQ_v_hc3h2cn_288_trotter']
TICKS = ['shor_rsa256', 'grover_3sat', 'chromium', 'ethylene', 'hc2h2cn']
VERSION=3

# %%
'''
    HINT PLOT SLOWDOWN FOR BASELINE CONFIGURATION
'''

baseline = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/baseline_a12')
eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_a12')
eif_la = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_la_a12')
hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a12')


# first, EIF vs baseline only ----------------------------

fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
plot_stat(ax, BENCHMARKS, TICKS,
              ['baseline', 'EIF', 'EIF-LA'], [baseline,eif,eif_la], ['', C1, C2],  # legend, configs, colors
              'CLIENT 0/KIPS', # stat_key
              'Slowdown',
              ylim=[0,30],
              normalize_results_to_policy='baseline',
              mean_type='gmean',
              inverted_normalization=True)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_eif_slowdown.pdf', bbox_inches='tight')

# second, EIF and HINT vs baseline -----------------------

fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
plot_stat(ax, BENCHMARKS, TICKS,
              ['baseline', 'EIF', 'EIF-LA', 'HINT'], [baseline,eif,eif_la,hint], ['', C1, C2, C3],  # legend, configs, colors
              'CLIENT 0/KIPS', # stat_key
              'Slowdown',
              ylim=[0,30],
              normalize_results_to_policy='baseline',
              mean_type='gmean',
              inverted_normalization=True)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_slowdown.pdf', bbox_inches='tight')


# raw instruction throughput plot
fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
plot_stat(ax, BENCHMARKS, TICKS,
              ['EIF', 'EIF-LA', 'HINT', 'Ideal'], [eif,eif_la,hint,baseline], [C1, C2, C3, C4],  # legend, configs, colors
              'CLIENT 0/KIPS', # stat_key
              'KIPS',
              ylim=[0,40],
     #         normalize_results_to_policy='baseline',
              mean_type='amean',
              inverted_normalization=True)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_slowdown_raw.pdf', bbox_inches='tight')
# Out:
# EIF 22.581198310867347 5.835107005028652 78.43046357615894 [ 5.83510701 17.4478294  78.43046358 26.74561404 27.49206349 22.58119831]
# EIF-LA 6.146630799589722 1.795350214719384 26.553811659192824 [ 5.69914335 17.05173055 26.55381166  1.89378882  1.79535021  6.1466308 ]
# EIF 22.581198310867347 5.835107005028652 78.43046357615894 [ 5.83510701 17.4478294  78.43046358 26.74561404 27.49206349 22.58119831]
# EIF-LA 6.146630799589722 1.795350214719384 26.553811659192824 [ 5.69914335 17.05173055 26.55381166  1.89378882  1.79535021  6.1466308 ]
# HINT 2.326165823862396 1.0624835684865481 11.322179732313575 [ 1.97937163  2.59136927 11.32217973  1.1038103   1.06248357  2.32616582]
# EIF 2.445 0.151 8.551 [8.551 2.626 0.151 0.456 0.441 2.445]
# EIF-LA 5.0161999999999995 0.446 8.755 [8.755  2.687  0.446  6.44   6.753  5.0162]
# HINT 13.279 1.046 25.208 [25.208 17.681  1.046 11.049 11.411 13.279]
# Ideal 26.375400000000003 11.843 49.896 [49.896  45.818  11.843  12.196  12.124  26.3754]

# %%
'''
    HINT PLOT COMPUTE INTENSITY
'''

eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/compiler_results/eif_a12')
eif_la = aggregate_stats_by_policy(f'{STATS_FOLDER}/compiler_results/eif_la_ld256_a12')
hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/compiler_results/hint_la_a12')

# EIF only ----------------------------------------------------

fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
plot_stat(ax, BENCHMARKS, TICKS,
            ['EIF'], [eif], [C1,C2], # legend, configs, colors
            'COMPUTE_INTENSITY',
            'Compute Intensity',
            mean_type='amean',
             legend_ncols=2)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_eif_compute_intensity.pdf', bbox_inches='tight')

# EIF and HINT ------------------------------------------------

fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
plot_stat(ax, BENCHMARKS, TICKS,
            ['EIF', 'EIF-LA', 'HINT'], [eif, eif_la, hint], [C1, C2, C3], # legend, configs, colors
            'COMPUTE_INTENSITY',
            'Compute Intensity',
            mean_type='amean',
         legend_ncols=3)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_compute_intensity.pdf', bbox_inches='tight')
# Out:
# EIF 100.696 14.222 307.875 [307.875  86.51   14.222  45.501  49.372 100.696]
# EIF 100.696 14.222 307.875 [307.875  86.51   14.222  45.501  49.372 100.696]
# EIF-LA 421.12299999999993 33.975 878.623 [316.236  87.904  33.975 788.877 878.623 421.123]
# HINT 790.4264000000001 34.665 1226.846 [1226.846  1001.323    34.665   796.233   893.065   790.4264]

# %%
'''
    HINT LOOKAHEAD DEPTH SENSITIVITY
        lookahead depth vs. mean compilation latency
        lookahead depth vs. mean compute intensity
'''

LOOKAHEAD_DEPTHS = [8, 16, 32, 64, 128, 256, 512]

# load the compiler results for each lookahead depth once (HINT and EIF-LA),
# plus EIF (which has no lookahead and is therefore a single value)
hint_ld_data = {ld: aggregate_stats_by_policy(f'{STATS_FOLDER}/compiler_results/hint_ld{ld}_a12')
                for ld in LOOKAHEAD_DEPTHS}
eif_la_ld_data = {ld: aggregate_stats_by_policy(f'{STATS_FOLDER}/compiler_results/eif_la_ld{ld}_a12')
                  for ld in LOOKAHEAD_DEPTHS}
eif_data = aggregate_stats_by_policy(f'{STATS_FOLDER}/compiler_results/eif_a12')

def _bench_mean(data, stat_key):
    vals = [float(_nested_dict_access(data[b], stat_key)) for b in BENCHMARKS]
    return sum(vals) / len(vals)  # arithmetic mean across benchmarks

def plot_lookahead_line(ax, ld_data, stat_key, color, label, fmt='o-'):
    Y = [_bench_mean(ld_data[ld], stat_key) for ld in LOOKAHEAD_DEPTHS]
    print(label, Y)
    ax.plot(LOOKAHEAD_DEPTHS, Y, fmt, color=color, ms=6, label=label)

def style_lookahead_ax(ax, ylabel, logy=False):
    ax.set_xscale('log', base=2)
    if logy:
        ax.set_yscale('log')
    ax.set_xticks(LOOKAHEAD_DEPTHS, [str(ld) for ld in LOOKAHEAD_DEPTHS], fontsize=10)
    #ax.set_xlabel('Lookahead Depth', fontsize=12)
    ax.set_ylabel(ylabel, fontsize=12)
    ax.grid(visible=True, zorder=0)

# lookahead depth vs. mean compilation latency -----------------

fig, (ax1, ax2) = plt.subplots(2,1, sharex=True)
fig.set_size_inches(6.0, 5.0)
eif_latency = _bench_mean(eif_data, 'COMPILATION_TIME_SECONDS')
print('EIF', eif_latency)
ax1.axhline(eif_latency, color='k', ls='--', label='EIF')
plot_lookahead_line(ax1, eif_la_ld_data, 'COMPILATION_TIME_SECONDS', C1, 'EIF-LA', fmt='x--')
plot_lookahead_line(ax1, hint_ld_data, 'COMPILATION_TIME_SECONDS', C3, 'HINT')
style_lookahead_ax(ax1, 'Compilation Latency (s)', logy=False)
ax1.legend(fontsize=10, ncols=3, loc='upper left')
ax1.set_ylim(0,500)

print('------------------')

# lookahead depth vs. mean compute intensity -------------------

eif_intensity = _bench_mean(eif_data, 'COMPUTE_INTENSITY')
print('EIF', eif_intensity)
ax2.axhline(eif_intensity, color='k', ls='--', label='EIF')
plot_lookahead_line(ax2, eif_la_ld_data, 'COMPUTE_INTENSITY', C1, 'EIF-LA', fmt='x--')
plot_lookahead_line(ax2, hint_ld_data, 'COMPUTE_INTENSITY', C3, 'HINT')
style_lookahead_ax(ax2, 'Compute Intensity')
ax2.set_xlabel('Lookahead Depth', fontsize=12)
ax2.set_ylim(0,900)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_lookahead_study.pdf', bbox_inches='tight')
# Out:
# EIF 72.8138
# EIF-LA [65.58059999999999, 65.12480000000001, 73.748, 114.56980000000001, 192.52640000000002, 301.43539999999996, 395.81180000000006]
# HINT [238.68560000000002, 188.2518, 137.0278, 129.4576, 148.2996, 184.87539999999996, 231.73019999999997]
# ------------------
# EIF 100.696
# EIF-LA [282.81059999999997, 361.548, 385.81679999999994, 389.229, 403.6326, 421.12299999999993, 428.15659999999997]
# HINT [476.44899999999996, 611.0505999999999, 721.4738, 764.1913999999999, 784.859, 790.2808000000001, 790.4570000000001]

# %%
'''
    HINT APPLICATION FIDELITY COMPARISON
'''

baseline = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/baseline_a12')
eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_a12')
eif_la = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_la_a12')
hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a12')

# EIF and HINT vs baseline -----------------------

fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
plot_stat(ax, BENCHMARKS, TICKS,
              ['EIF', 'EIF-LA', 'HINT', 'Ideal'], [eif,eif_la,hint,baseline], [C1, C2, C3, C4],  # legend, configs, colors
              'CLIENT_0_FIDELITY/OVERALL', # stat_key
              'Application Fidelity',
              ylim=[0.8,1.0],
            #  show_percentage=True,
           #   normalize_results_to_policy='Ideal',
              mean_type='amean'
              )
ax.legend(loc='lower right', framealpha=1.0, ncols=4)
for label in ax.get_yticklabels():
    if label.get_text() in ('0.80'):
        label.set_bbox(dict(boxstyle='circle,pad=0.3', facecolor='none', edgecolor='red', linewidth=1.5))
        break
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_fidelity.pdf', bbox_inches='tight')
# Out:
# EIF 0.9344000000000001 0.861 0.981 [0.861  0.981  0.933  0.951  0.946  0.9344]
# EIF-LA 0.9632 0.864 0.997 [0.864  0.982  0.976  0.997  0.997  0.9632]
# HINT 0.9874 0.956 0.998 [0.956  0.998  0.987  0.998  0.998  0.9874]
# Ideal 0.9962 0.986 0.999 [0.986  0.999  0.999  0.999  0.998  0.9962]

# %%
'''
    HINT PERFORMANCE/QUBIT SENSITIVITY
'''

fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)
ax.set_xlabel('Relative Qubit Count', fontsize=12)
ax.set_ylabel('Speedup (%)', fontsize=12)

reference = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a12')

def _get_qubit_count(d, benchmark) -> float:
    qubits = float(_nested_dict_access(d[benchmark], 'COMPUTE_PHYSICAL_QUBITS'))
    if 'ED_PHYSICAL_QUBITS' in d[benchmark]:
        qubits += float(_nested_dict_access(d[benchmark], 'ED_PHYSICAL_QUBITS'))/9374 * 17096
    return qubits

def _get_relative_qubit_count(d):
    b = BENCHMARKS[0]  # only need one benchmark since only the computes ubsystem capacity and EPR overhead changes
    return _get_qubit_count(d, b) / _get_qubit_count(reference, b)

# first, plot the slowdowns w.r.t. varying EPR buffer capacity\
X_epr, Y_epr = [], []
for u in [2, 4, 8]:
    if u == 2:
        policy = 'hint_a12'
    elif u == -1:
        policy = 'hint_ed_sensitivity_perfect'
    else:
        policy = f'hint_ed_sensitivity_u{u}'
    d = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/{policy}')
    # compute gmean:
    x = _get_relative_qubit_count(d)
    _Y = []
    for b in BENCHMARKS:
        ref = float(_nested_dict_access(reference[b], 'CLIENT 0/KIPS'))
        y = float(_nested_dict_access(d[b], 'CLIENT 0/KIPS'))
        _Y.append(y/ref)        
    gm = sp.stats.gmean(_Y)
    X_epr.append(x)
    Y_epr.append((gm-1)*100)
print(np.array(X_epr), np.array(Y_epr))
ax.plot(X_epr, Y_epr, 'o-', color=C1, ms=8)

# second, plot the speedups w.r.t. varying compute subsystem capacity
X_a, Y_a = [], []
for a in [12, 16, 24]:
    policy = f'hint_a{a}'
    d = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/{policy}')
    x = _get_relative_qubit_count(d)
    _Y = []
    for b in BENCHMARKS:
        ref = float(_nested_dict_access(reference[b], 'CLIENT 0/KIPS'))
        y = float(_nested_dict_access(d[b], 'CLIENT 0/KIPS'))
        _Y.append(y/ref)        
    gm = sp.stats.gmean(_Y)
    X_a.append(x)
    Y_a.append((gm-1)*100)
print(np.array(X_a), np.array(Y_a))
ax.plot(X_a, Y_a, 'x--', color=C4, ms=8)
# Out:
# [1.         1.44869765 2.34609294] [ 0.         16.48535503 23.03673978]
# [1.         1.12975226 1.38925677] [ 0.         25.99915265 68.44060446]

# %%
'''
    HINT compute subsystem capacity sensitivity 
'''

for a in [8, 12, 16, 24, 32]:
    baseline = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/baseline_a{a}')
    eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_a{a}')
    hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a{a}')
    Y_eif, Y_hint = [], []
    for b in BENCHMARKS:
        b_kips = float(_nested_dict_access(baseline[b], 'CLIENT 0/KIPS'))
        eif_kips = float(_nested_dict_access(eif[b], 'CLIENT 0/KIPS'))
        hint_kips = float(_nested_dict_access(hint[b], 'CLIENT 0/KIPS'))

        Y_eif.append(b_kips/eif_kips)
        Y_hint.append(b_kips/hint_kips)
    eif_slowdown = sp.stats.gmean(Y_eif)
    hint_slowdown = sp.stats.gmean(Y_hint)
    gap_closed = 1 - (hint_slowdown-1)/(eif_slowdown-1)
    print(f'a = {a}, eif = {eif_slowdown}, hint = {hint_slowdown}, gap closed = {gap_closed}')
# Out:
# a = 8, eif = 22.89344598545657, hint = 3.102868635633677, gap closed = 0.903949856179307
# a = 12, eif = 20.791254940414543, hint = 2.2036693453653555, gap closed = 0.9391817573474124
# a = 16, eif = 19.243704015411012, hint = 1.8078417518865173, gap closed = 0.9557194223714598
# a = 24, eif = 16.05533531096067, hint = 1.3582096759566094, gap closed = 0.976207127336724
# a = 32, eif = 15.665871122747147, hint = 1.1826125484261438, gap closed = 0.9875484690341437

# %%
'''
    HINT memory subsystem sensitivity
'''

for smf in [10, 50, 100, 500]:
    baseline = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/baseline_a12')
    eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_mismatch_sensitivity_smf{smf}')
    hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_mismatch_sensitivity_smf{smf}')
    Y_eif, Y_hint = [], []
    for b in BENCHMARKS:
        b_kips = float(_nested_dict_access(baseline[b], 'CLIENT 0/KIPS'))
        eif_kips = float(_nested_dict_access(eif[b], 'CLIENT 0/KIPS'))
        hint_kips = float(_nested_dict_access(hint[b], 'CLIENT 0/KIPS'))

        Y_eif.append(b_kips/eif_kips)
        Y_hint.append(b_kips/hint_kips)
    eif_slowdown = sp.stats.gmean(Y_eif)
    hint_slowdown = sp.stats.gmean(Y_hint)
    gap_closed = 1 - (hint_slowdown-1)/(eif_slowdown-1)
    print(f'smf = {smf}, eif = {eif_slowdown}, hint = {hint_slowdown}, gap closed = {gap_closed}')
    print('\t', Y_eif, Y_hint)
# Out:
# smf = 10, eif = 1.1807963249944597, hint = 1.068793083518587, gap closed = 0.6194995472352931
# 	 [1.0036125477558022, 1.027221366204417, 1.6126471393375308, 1.1791969037252055, 1.1708982496633968] [1.0778764026126277, 1.4968290857525506, 0.9325629254392908, 0.961499013806706, 0.9640509937445563]
# smf = 50, eif = 1.8648705097502523, hint = 1.1449218896440816, gap closed = 0.8324351587777798
# 	 [1.0243785977664004, 1.2201778890922519, 4.64040961008271, 1.9968867769949206, 1.9473768394113886] [1.089216709446309, 1.5149099027268378, 1.280373831775701, 0.9641613924050632, 0.9658099317785183]
# smf = 100, eif = 2.6689741157411935, hint = 1.2255679796566654, gap closed = 0.8648463283347625
# 	 [1.0722496806797355, 1.5979814970563497, 8.4519368723099, 3.096290650406504, 3.020342346812206] [1.103976671717316, 1.5357258325250567, 1.7410964977094723, 0.9675293744045729, 0.9681138676844784]
# smf = 500, eif = 10.45319331703077, hint = 1.7016356331748463, gap closed = 0.925777923962394
# ...

# %%
'''
    HINT entanglement distillation sensitivity
'''

baseline = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/baseline_a12')
for u in [2, 4, 8, 16, -1]:
    if u == 2:
        eif_folder = 'eif_a12'
        hint_folder = 'hint_a12'
    elif u == -1:
        eif_folder = 'eif_ed_sensitivity_perfect'
        hint_folder = 'hint_ed_sensitivity_perfect'
    else:
        eif_folder = f'eif_ed_sensitivity_u{u}'
        hint_folder = f'hint_ed_sensitivity_u{u}'
    eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/{eif_folder}')
    hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/{hint_folder}')

    Y_eif, Y_hint = [], []
    for b in BENCHMARKS:
        b_kips = float(_nested_dict_access(baseline[b], 'CLIENT 0/KIPS'))
        eif_kips = float(_nested_dict_access(eif[b], 'CLIENT 0/KIPS'))
        hint_kips = float(_nested_dict_access(hint[b], 'CLIENT 0/KIPS'))

        Y_eif.append(b_kips/eif_kips)
        Y_hint.append(b_kips/hint_kips)
    eif_slowdown = sp.stats.gmean(Y_eif)
    hint_slowdown = sp.stats.gmean(Y_hint)
    gap_closed = 1 - (hint_slowdown-1)/(eif_slowdown-1)
    print(f'u = {u}, eif = {eif_slowdown}, hint = {hint_slowdown}, gap closed = {gap_closed}')
    print('\t', Y_eif, Y_hint)
# Out:
# u = 2, eif = 20.791254940414543, hint = 2.2036693453653555, gap closed = 0.9391817573474124
# 	 [4.598237675637057, 14.45966514459665, 82.3916083916084, 27.203124999999996, 26.07066381156317] [1.6392579700301397, 2.1914648212226067, 12.428270042194093, 1.0938874427789247, 1.0640622268834121]
# u = 4, eif = 15.85916926252461, hint = 1.9007647713443312, gap closed = 0.9393798700701194
# 	 [2.8505204104229716, 8.968609865470851, 72.72839506172839, 23.71011673151751, 22.757009345794394] [1.418454305024978, 1.9528238861195335, 8.350106307583275, 1.045018007202881, 1.0264733159092825]
# u = 8, eif = 14.090266985895875, hint = 1.7959523291095478, gap closed = 0.9391951035095657
# 	 [2.4948959813929448, 6.967363403006968, 68.10404624277457, 22.11796733212341, 21.210801393728225] [1.4110940583205438, 1.9449278329409356, 6.351482479784367, 1.044659694839705, 1.02604078880836]
# u = 16, eif = 13.869144386610525, hint = 1.7549263480647368, gap closed = 0.9413382641933689
# ...

# %%
'''
    Physical qubit resource estimates
'''

def _get_qubit_count(d, benchmark) -> float:
    qubits = float(_nested_dict_access(d[benchmark], 'COMPUTE_PHYSICAL_QUBITS'))
    qubits += float(_nested_dict_access(d[benchmark], 'MEMORY_PHYSICAL_QUBITS'))
    qubits += float(_nested_dict_access(d[benchmark], 'FACTORY_PHYSICAL_QUBITS'))
    if 'ED_PHYSICAL_QUBITS' in d[benchmark]:
        qubits += 17096#float(_nested_dict_access(d[benchmark], 'ED_PHYSICAL_QUBITS'))
    return qubits

def _get_program_qubit_count(b) -> int:
    counts = [514, 1710, 121, 241, 289]
    idx = BENCHMARKS.index(b)
    return counts[idx]

hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a12')
Y = []
ED_FRACTION = []
for b in BENCHMARKS:
    Q = _get_program_qubit_count(b)
    # forgot to account for memory subsystem routing overhead:
    hint_correction = math.ceil((Q-12)/12) * (2*21*(21+1)) * 0.5
    
    hint_pq_count = _get_qubit_count(hint, b) + hint_correction
    mono_pq_count = (2*25*(25+1))*1.5*Q + float(_nested_dict_access(hint[b], 'FACTORY_PHYSICAL_QUBITS'))
    ed_fraction = 17096 / hint_pq_count
    print(f'{b}\tmono = {mono_pq_count}\thint = {hint_pq_count}\timprovement = {mono_pq_count/hint_pq_count}, fraction for ed = {ed_fraction}')
    Y.append(mono_pq_count/hint_pq_count)
    ED_FRACTION.append(ed_fraction)
print(f'gmean improvement = {sp.stats.gmean(Y)}, gmean ed fraction = {sp.stats.gmean(ED_FRACTION)}')
# Out:
# BQ_shor_rsa256_iter_4.rpc	mono = 1050516.0	hint = 169772.0	improvement = 6.187804820582899, fraction for ed = 0.10069976203378649
# BQ_grover_3sat_schoning_1710.rpc	mono = 3382716.0	hint = 371172.0	improvement = 9.113607707477934, fraction for ed = 0.04605950879915511
# BQ_e_cr2_120_trotter.rpc	mono = 284166.0	hint = 105324.0	improvement = 2.6980175458584936, fraction for ed = 0.16231818009190688
# BQ_v_c2h4o_ethylene_oxide_240_trotter.rpc	mono = 518166.0	hint = 125464.0	improvement = 4.129997449467576, fraction for ed = 0.13626219473315054
# BQ_v_hc3h2cn_288_trotter.rpc	mono = 611766.0	hint = 133520.0	improvement = 4.581830437387658, fraction for ed = 0.1280407429598562
# gmean improvement = 4.918719997018065, gmean ed fraction = 0.10560578162352915

# %%
'''
    Stall breakdown
'''

def plot_stall_breakdown(ax,
                         benchmark_list: list[str],
                         benchmark_ticks: list[str],
                         config: dict):
    categories = ['Iso. Memory', 'Iso. EPR', 'Iso. Factory', 'Non-isolated', 'No Stall']
    cat_colors = [C1, C2, C3, C4, 'white']

    n_benchmarks = len(benchmark_list)
    benchmark_x = np.arange(n_benchmarks + 1)
    ticks = [*benchmark_ticks, 'amean']
    width = 0.5

    all_fracs = np.zeros((n_benchmarks, len(categories)))

    for (bi, b) in enumerate(benchmark_list):
        total_cycles = float(_nested_dict_access(config[b], 'TOTAL_SIMULATION_CYCLES'))
        iso_mem      = float(_nested_dict_access(config[b], 'ISOLATED_MEMORY_STALLS'))
        iso_epr      = float(_nested_dict_access(config[b], 'ISOLATED_EPR_STALLS'))
        iso_fact     = float(_nested_dict_access(config[b], 'ISOLATED_MAGIC_STATE_STALLS'))
        total_stalls = float(_nested_dict_access(config[b], 'TOTAL_STALLS'))

        non_iso  = total_stalls - iso_mem - iso_epr - iso_fact
        no_stall = total_cycles - total_stalls

        all_fracs[bi] = np.array([iso_mem, iso_epr, iso_fact, non_iso, no_stall]) / total_cycles * 100

    # append arithmetic mean
    mean_fracs = all_fracs.mean(axis=0)
    all_fracs = np.vstack([all_fracs, mean_fracs])

    for (ci, cat) in enumerate(categories):
        print(f'{cat}: {mean_fracs[ci]:.2f}%')

    for bi in range(n_benchmarks + 1):
        bottom = 0.0
        for (ci, cat) in enumerate(categories):
            label = cat if bi == 0 else None
            ax.bar(benchmark_x[bi], all_fracs[bi, ci], width, bottom=bottom,
                   color=cat_colors[ci], edgecolor='k', linewidth=0.5,
                   zorder=3, label=label)
            bottom += all_fracs[bi, ci]

    ax.set_ylabel('% of Compute Cycles', fontsize=12)
    ax.set_ylim(0, 100)
    ax.set_xticks(benchmark_x, ticks, rotation=30, ha='right', fontsize=10)
    ax.grid(visible=True, axis='y', zorder=0)
    ax.legend(fontsize=10, ncols=1, loc='upper left', bbox_to_anchor=(1.0, 0.8))

eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_la_a12')
hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a12')

fig, ax = plt.subplots()
fig.set_size_inches(4.5, 2.4)
plot_stall_breakdown(ax, BENCHMARKS, TICKS, eif)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_eif_stall_breakdown.pdf', bbox_inches='tight')

print('------------------')

fig, ax = plt.subplots()
fig.set_size_inches(4.5, 2.4)
plot_stall_breakdown(ax, BENCHMARKS, TICKS, hint)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_stall_breakdown.pdf', bbox_inches='tight')
# Out:
# Iso. Memory: 34.73%
# Iso. EPR: 43.03%
# Iso. Factory: 0.31%
# Non-isolated: 5.37%
# No Stall: 16.56%
# ------------------
# Iso. Memory: 17.83%
# Iso. EPR: 43.09%
# Iso. Factory: 2.28%
# Non-isolated: 1.96%
# No Stall: 34.84%

# %%
'''
    HINT factory sensitivity
'''


fig, ax = plt.subplots()
fig.set_size_inches(6.0,2.4)

policies = ['baseline']
baseline = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/baseline_a12')
data = [baseline]

for f in [10000, 25000, 50000, 100000]:
    if f == 50000:
        folder = 'hint_a12'
    else:
        folder = f'hint_factory_sensitivity_f{f}'
    d = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/{folder}')
    pq_count = int(d[BENCHMARKS[0]]['FACTORY_PHYSICAL_QUBITS'])
    policy_name = f'{pq_count//1000}k qubits'
    if f == 50000:
        policy_name = f'{policy_name}*'
    policies.append(policy_name)
    data.append(d)

plot_stat(ax, BENCHMARKS, TICKS,
            policies, data, [C1,C1,C2,C3,C4], # legend, configs, colors
              'CLIENT 0/KIPS', # stat_key
              'Slowdown',
              normalize_results_to_policy='baseline',
              mean_type='gmean',
              inverted_normalization=True)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_factory_sensitivity.pdf', bbox_inches='tight')
# Out:
# 8k qubits 4.6631211598042634 2.0041152263374484 12.83442265795207
# 24k qubits 2.4694102017967965 1.0636903721824218 12.441393875395988
# 48k qubits* 2.2036693453653555 1.0640622268834121 12.428270042194093
# 96k qubits 2.138612928025967 1.0629474419416798 12.428270042194093

# %%
'''
    HINT and EIF physical EPR bandwidth consumption
'''

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)

PHYSICAL_EPR_TO_LOGICAL_EPR_RATE = 3.1384  # computed in simulation
CYCLE_TIME_S = 1.2e-6  # each compute/simulation cycle is 1.2us

eif = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/eif_a12')
hint = aggregate_stats_by_policy(f'{STATS_FOLDER}/simulation_results/hint_a12')

benchmark_x = np.arange(len(TICKS) + 1)
ticks = [*TICKS, 'amean']
width = 1.0 / 3
offset = 0

for (policy_name, config, color) in [('EIF', eif, C1), ('HINT', hint, C2)]:
    Y = []
    for b in BENCHMARKS:
        memory_accesses = float(_nested_dict_access(config[b], 'CLIENT 0/MEMORY_ACCESSES'))
        total_cycles = float(_nested_dict_access(config[b], 'TOTAL_SIMULATION_CYCLES'))

        logical_eprs = memory_accesses * 2
        physical_eprs = logical_eprs * PHYSICAL_EPR_TO_LOGICAL_EPR_RATE
        elapsed_time_s = total_cycles * CYCLE_TIME_S

        print(policy_name, b, physical_eprs/1000000)

        bandwidth = physical_eprs / elapsed_time_s  # physical EPR pairs per second
        Y.append(bandwidth)

    Y.append(sum(Y) / len(Y))  # amean
    Y = np.array(Y)
    print(policy_name, Y)

    ax.bar(benchmark_x + offset, Y, width, color=color, edgecolor='k', zorder=3, label=policy_name)
    offset += width

workload_x_ticks = benchmark_x + 0.5 * width
ax.set_xticks(workload_x_ticks, ticks, rotation=30, ha='right', fontsize=10)
ax.set_ylabel('Physical EPR Pairs / s', fontsize=12)
ax.grid(visible=True, axis='y', zorder=0)
ax.legend(fontsize=10)
plt.savefig(f'{PLOT_FOLDER}/v{VERSION}_hint_eif_epr_bandwidth.pdf', bbox_inches='tight')
# Out:
# EIF BQ_shor_rsa256_iter_4 0.2956498336
# EIF BQ_grover_3sat_schoning_1710 1.0273489632
# EIF BQ_e_cr2_120_trotter 5.4551606031999995
# EIF BQ_v_c2h4o_ethylene_oxide_240_trotter 1.8251176895999999
# EIF BQ_v_hc3h2cn_288_trotter 1.8830525536
# EIF [252.81072229 269.80096432  82.41375275  83.26500305  83.11842037
#  154.28177255]
# HINT BQ_shor_rsa256_iter_4 0.07534043039999999
# HINT BQ_grover_3sat_schoning_1710 0.0898084544
# HINT BQ_e_cr2_120_trotter 2.0693919151999998
# HINT BQ_v_c2h4o_ethylene_oxide_240_trotter 0.11214758559999999
# HINT BQ_v_hc3h2cn_288_trotter 0.0990667344
# HINT [189.91465992 158.78770105 216.37493098 123.91177907 113.04067919
#  160.40595004]

# %%
### QOS 
C_DATA_FOLDER = '../out/qoc/compiled_results'
S_DATA_FOLDER = '../out/qoc/simulation_results'
PLOTS = 'plots/qoc'

s_baseline_l2 = get_simulation_policy_results('baseline_l2', S_DATA_FOLDER)
s_l2_no_depop = get_simulation_policy_results('l2_no_depop', S_DATA_FOLDER)
s_l2_depop = get_simulation_policy_results('l2_depop', S_DATA_FOLDER)

s_baseline_l1 = get_simulation_policy_results('baseline_l1', S_DATA_FOLDER)
s_l1_no_depop = get_simulation_policy_results('l1_no_depop', S_DATA_FOLDER)
s_l1_depop = get_simulation_policy_results('l1_depop', S_DATA_FOLDER)
C1 = '#f0f9e8'
C2 = '#bae4bc'
C3 = '#7bccc4'
C4 = '#43a2ca'
C5 = '#0868ac'

# %%
# Two level distillation speedups

baseline = filter_policy_by_suffix(s_baseline_l2, 'r0_10M')
configs_1 = []
configs_2 = []

for r in [20, 30, 40, 50]:
    configs_1.append(filter_policy_by_suffix(s_l2_no_depop, f'r{r}_10M'))
    rr = int(1.3*r)
    configs_2.append(filter_policy_by_suffix(s_l2_depop, f'r{rr}_10M'))

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)
plot_relative_stat(ax, baseline,
                       configs_1,
                       [C1,C2,C3,C4],
                       ['20%', '30%', '40%', '50%'],
                       'kips',
                       'Speedup (%)',
                       plot_as_percentage=True,
                       baseline_on_top=False)
ax.legend(bbox_to_anchor=(0.9,1.15), ncols=4, loc='upper right', framealpha=1)
plt.savefig(f'{PLOTS}/two_level_distillation_no_depop.pdf', bbox_inches='tight')

print('------------------------------')

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)
plot_relative_stat(ax, baseline,
                       configs_2,
                       [C1,C2,C3,C4],
                       ['20%', '30%', '40%', '50%'],
                       'kips',
                       'Speedup (%)',
                       plot_as_percentage=True,
                       baseline_on_top=False)
ax.legend(bbox_to_anchor=(0.9,1.15), ncols=4, loc='upper right', framealpha=1)
plt.savefig(f'{PLOTS}/two_level_distillation_depop.pdf', bbox_inches='tight')
# Out:
# 20% 1.15803742521364 1.1620251555336614
# 30% 1.3367058633739972 1.3414907394900564
# 40% 1.3948987407503475 1.4128177217000248
# 50% 1.617748586464149 1.766345932288232
# ------------------------------
# 20% 1.4943046269972475 2.3687438918772896
# 30% 1.5178804767460627 2.3726530904121343
# 40% 1.614748024699992 2.356332981081704
# 50% 1.7276890939126042 2.40935347259191

# %%
# Single-level distillation speedups
baseline = filter_policy_by_suffix(s_baseline_l1, 'r0_10M')
configs_1 = []
configs_2 = []

for r in [20, 30, 40, 50]:
    configs_1.append(filter_policy_by_suffix(s_l1_no_depop, f'r{r}_10M'))
    rr = int(1.3*r)
    configs_2.append(filter_policy_by_suffix(s_l1_depop, f'r{rr}_10M'))

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)
plot_relative_stat(ax, baseline,
                       configs_1,
                       [C1,C2,C3,C4],
                       ['20%', '30%', '40%', '50%'],
                       'kips',
                       'Speedup (%)',
                       plot_as_percentage=True,
                       baseline_on_top=False)
ax.legend(bbox_to_anchor=(0.9,1.15), ncols=4, loc='upper right', framealpha=1)
plt.savefig(f'{PLOTS}/one_level_distillation_no_depop.pdf', bbox_inches='tight')

print('------------------------------')

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)
plot_relative_stat(ax, baseline,
                       configs_2,
                       [C1,C2,C3,C4],
                       ['20%', '30%', '40%', '50%'],
                       'kips',
                       'Speedup (%)',
                       plot_as_percentage=True,
                       baseline_on_top=False)
ax.legend(bbox_to_anchor=(0.9,1.15), ncols=4, loc='upper right', framealpha=1)
plt.savefig(f'{PLOTS}/one_level_distillation_depop.pdf', bbox_inches='tight')
# Out:
# 20% 1.1966801852835791 1.1972966798189553
# 30% 1.315915353921341 1.3164045427343818
# 40% 1.4800230518058979 1.4809600553260596
# 50% 1.6754454510274546 1.6764289992528512
# ------------------------------
# 20% 1.5959912044711053 3.2435395053678757
# 30% 1.7836855896042003 3.2413510390373332
# 40% 1.994086925956946 3.2403891467563573
# 50% 2.184284364116207 3.2874768703913393

# %%
## sensitivity study on factory footprint
baselines = []
configs = []

for p in [3000, 6000, 12000, 24000]:
    if p == 12000:
        b = filter_policy_by_suffix(s_baseline_l2, 'r0_10M')
        conf = filter_policy_by_suffix(s_l2_no_depop, 'r30_10M')
    else:
        b = filter_policy_by_suffix(get_simulation_policy_results(f'baseline_fact{p}', S_DATA_FOLDER), 'r0_10M')
        conf = filter_policy_by_suffix(get_simulation_policy_results(f'l2_fact{p}', S_DATA_FOLDER), 'r30_10M')

    baselines.append(b)
    configs.append(conf)

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)
plot_relative_stat(ax, baselines, configs,
                       [C1, C2, C3, C4],
                       ['0.25x', '0.5x', '1x*', '2x'],
                        'kips',
                        'Speedup (%)',
                        plot_as_percentage=True,
                        baseline_on_top=False)
ax.legend(bbox_to_anchor=(0.9,1.2), ncols=4, loc='upper right')
plt.savefig(f'{PLOTS}/factory_sensitivity.pdf', bbox_inches='tight')
# Out:
# 0.25x 1.254258716335442 1.2552058156397574
# 0.5x 1.36720494059547 1.368148474844501
# 1x* 1.3367058633739972 1.3414907394900564
# 2x 1.0616347522282021 1.1705903699600817

# %%
## motivational data

baseline = filter_policy_by_suffix(s_baseline_l2, 'r0_10M')
configs = []
for cf in ['m_reduce_all', 'm_reduce_cmp', 'm_reduce_mem', 'm_reduce_fact']:
    s_x = get_simulation_policy_results(cf, S_DATA_FOLDER)
    configs.append(filter_policy_by_suffix(s_x, 'r20_10M'))

fig, ax = plt.subplots()
fig.set_size_inches(6.0, 2.4)
plot_relative_stat(ax, baseline, configs,
                        [C1,C2,C3,C4],
                        ['All', 'Compute Only', 'Memory Only', 'Factory Only'],
                        'kips',
                        'Speedup (%)',
                        plot_as_percentage=True,
                        baseline_on_top=False)
ax.legend(bbox_to_anchor=(0.85,1.3), ncols=2, loc='upper right')
plt.savefig(f'{PLOTS}/speedup_sensitivity.pdf', bbox_inches='tight')
# Out:
# All 1.1576910794243942 1.16196953685532
# Compute Only 0.9998030786146868 1.0001668560350239
# Memory Only 0.9999912869318565 1.0001112373566825
# Factory Only 1.15803742521364 1.1620251555336614
